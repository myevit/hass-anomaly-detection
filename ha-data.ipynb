# %%
pip install pandas influxdb-client river holidays scikit-learn
# Out:
# Requirement already satisfied: pandas in /opt/conda/lib/python3.11/site-packages (2.2.3)
# Requirement already satisfied: influxdb-client in /opt/conda/lib/python3.11/site-packages (1.48.0)
# Requirement already satisfied: river in /opt/conda/lib/python3.11/site-packages (0.22.0)
# Requirement already satisfied: holidays in /opt/conda/lib/python3.11/site-packages (0.70)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.11/site-packages (1.6.1)
# Requirement already satisfied: numpy>=1.23.2 in /opt/conda/lib/python3.11/site-packages (from pandas) (2.2.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.11/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.11/site-packages (from pandas) (2025.2)
# Requirement already satisfied: reactivex>=4.0.4 in /opt/conda/lib/python3.11/site-packages (from influxdb-client) (4.0.4)
# Requirement already satisfied: certifi>=14.05.14 in /opt/conda/lib/python3.11/site-packages (from influxdb-client) (2023.7.22)
# Requirement already satisfied: setuptools>=21.0.0 in /opt/conda/lib/python3.11/site-packages (from influxdb-client) (68.2.2)
# Requirement already satisfied: urllib3>=1.26.0 in /opt/conda/lib/python3.11/site-packages (from influxdb-client) (2.0.7)
# Requirement already satisfied: scipy<2.0.0,>=1.14.1 in /opt/conda/lib/python3.11/site-packages (from river) (1.15.2)
# Requirement already satisfied: joblib>=1.2.0 in /opt/conda/lib/python3.11/site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /opt/conda/lib/python3.11/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.1.1 in /opt/conda/lib/python3.11/site-packages (from reactivex>=4.0.4->influxdb-client) (4.8.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import os
import pandas as pd
from datetime import datetime, timedelta
from dateutil import parser
from influxdb_client import InfluxDBClient
from river import anomaly
from river import preprocessing
import pickle
import holidays
from sklearn.feature_extraction.text import TfidfVectorizer
from scipy.stats import zscore
from river import linear_model

# --- CONFIG ---
INFLUX_URL = "http://192.168.1.4:8086"
TOKEN = "LY86Tqy1cg5-UYTYPMmHI5opIxC2_NtLiZexyHehiqmL7YLGyHOyEeosm9JXAnoVuNaZT5TYNNcMW1eQK3qW3g=="
ORG = "myeHome"
BUCKET = "home-assistant"
SAVE_MODEL_PATH = "river_model.pkl"
META_MODEL_PATH = "meta_model.pkl"
SAVE_TIMESTAMP_PATH = "last_cutoff.txt"
CHUNK_SIZE = "5min"
MISSING_TOKEN = "NaN"

# %%
# --- Influx connection ---
client = InfluxDBClient(url=INFLUX_URL, token=TOKEN, org=ORG)
query_api = client.query_api()

# --- Load or init model ---
if os.path.exists(SAVE_MODEL_PATH):
    with open(SAVE_MODEL_PATH, "rb") as f:
        model = pickle.load(f)
else:
    model = preprocessing.StandardScaler() | anomaly.HalfSpaceTrees(n_trees=25, height=15, window_size=250)

# Load or init meta model
if os.path.exists(META_MODEL_PATH):
    with open(META_MODEL_PATH, "rb") as f:
        meta_model = pickle.load(f)
else:
    meta_model = linear_model.LogisticRegression()

# --- Load last cutoff time ---
if os.path.exists(SAVE_TIMESTAMP_PATH):
    with open(SAVE_TIMESTAMP_PATH, "r") as f:
        last_cutoff_str = f.read().strip()
        last_cutoff = parser.isoparse(last_cutoff_str)
else:
    last_cutoff = datetime.utcnow() - timedelta(days=7)

now = datetime.utcnow()
start = last_cutoff.replace(microsecond=0).isoformat() + "Z"
stop = now.replace(microsecond=0).isoformat() + "Z"
print(f"⏱️ Querying from {start} to {stop}...")
# Out:
# ⏱️ Querying from 2025-04-08T01:23:11Z to 2025-04-15T01:23:11Z...

# %%
# --- Query InfluxDB ---

query = f'''
from(bucket: "{BUCKET}")
  |> range(start: {start}, stop: {stop})
  |> filter(fn: (r) => r["_field"] == "value")
  |> filter(fn: (r) => r["_measurement"] == "state")
  |> pivot(rowKey: ["_time"], columnKey: ["entity_id"], valueColumn: "_value")
'''
df = query_api.query_data_frame(query)
df = pd.concat(df) if isinstance(df, list) else df
if df.empty:
    print("⚠️ No new data found.")
    exit()

# --- Separate numeric and text columns ---
df = df.set_index("_time").sort_index()
numeric_df = df.select_dtypes(include="number")
text_df = df.select_dtypes(include="object")


# --- Resample numeric data ---
numeric_df = numeric_df.resample(CHUNK_SIZE).mean().interpolate().ffill().bfill()

# --- Add context features ---
ca_holidays = holidays.CA(prov='AB')

def add_context_features(chunk):
    chunk["hour"] = chunk.index.hour
    chunk["day_of_week"] = chunk.index.dayofweek
    chunk["is_weekend"] = (chunk["day_of_week"] >= 5).astype(int)
    chunk["month"] = chunk.index.month
    chunk["season"] = chunk["month"].map({
        12: 0, 1: 0, 2: 0,
        3: 1, 4: 1, 5: 1,
        6: 2, 7: 2, 8: 2,
        9: 3, 10: 3, 11: 3
    })
    chunk["is_holiday"] = chunk.index.normalize().isin(ca_holidays).astype(int)
    return chunk

numeric_df = add_context_features(numeric_df)

# --- Prepare TF-IDF encoders for text columns ---
text_df = text_df.resample(CHUNK_SIZE).first().fillna("")
text_columns = text_df.columns.tolist()
vectorizers = {col: TfidfVectorizer(max_features=5) for col in text_columns}
for col in text_columns:
    try:
        vectorizers[col].fit(text_df[col].astype(str))
    except:
        pass

# %%
def remand_compare(current_vector: dict, timestamp: pd.Timestamp, df_full: pd.DataFrame, weeks=8, z_thresh=3.0):
    """
    Compare current vector to same (weekday, hour, minute) slots in previous weeks.
    - current_vector: dict of current feature values
    - timestamp: timestamp of the current vector
    - df_full: historical data with datetime index
    - weeks: how many past weeks to compare
    - z_thresh: z-score threshold for anomaly flag
    """

    # Extract context
    target_dow = timestamp.dayofweek
    target_hour = timestamp.hour
    target_minute = timestamp.minute

    # Filter to matching weekly slot
    historical = df_full[
        (df_full.index.dayofweek == target_dow) &
        (df_full.index.hour == target_hour) &
        (df_full.index.minute == target_minute) &
        (df_full.index < timestamp)
    ].tail(weeks)  # limit to last N matching weeks

    if len(historical) < 3:
        print(f"[{timestamp}] ⚠️ Not enough matching history for remand")
        return None, False

    # Build comparison frame
    try:
        hist_df = pd.DataFrame(historical)
        cur_df = pd.DataFrame([current_vector], index=[timestamp])
        full_df = pd.concat([hist_df, cur_df])

        # Calculate z-scores
        zs = zscore(full_df, nan_policy="omit")
        current_z = zs[-1]

        # Count how many features exceed the threshold
        z_dict = dict(zip(full_df.columns, current_z))
        outliers = {k: z for k, z in z_dict.items() if abs(z) > z_thresh}
        is_anomaly = len(outliers) > 0

        print(f"[{timestamp}] 📊 Remand Z-anomaly | outliers: {len(outliers)}, max z: {max(outliers.values(), default=0):.2f}")
        return outliers, is_anomaly

    except Exception as e:
        print(f"[{timestamp}] ❌ Remand error: {e}")
        return None, False

# %%
def compare_to_yesterday(current_vector: dict, timestamp: pd.Timestamp, df_full: pd.DataFrame, z_thresh=3.0):
    """Compare current vector to same time yesterday"""
    yesterday_time = timestamp - timedelta(days=1)

    if yesterday_time not in df_full.index:
        print(f"[{timestamp}] ⚠️ No matching time yesterday")
        return None, False

    hist_vector = df_full.loc[yesterday_time]

    # Compute z-score per feature
    z_scores = {}
    outlier_count = 0
    for k in current_vector:
        if k in hist_vector and pd.notna(hist_vector[k]):
            std = np.std([hist_vector[k], current_vector[k]])
            if std == 0:
                continue  # identical values → not outlier
            z = abs(current_vector[k] - hist_vector[k]) / std
            z_scores[k] = z
            if z > z_thresh:
                outlier_count += 1

    print(f"[{timestamp}] 🕒 Yesterday diff | outliers: {outlier_count}, max z: {max(z_scores.values() or [0]):.2f}")
    outliers = {k: z for k, z in z_scores.items() if z > z_thresh}
    return outliers, len(outliers) > 0

# %%
# --- Merge numeric + encoded text and run model ---
for ts in numeric_df.index:
    x = numeric_df.loc[ts].to_dict()

    # --- TF-IDF: handle text features ---
    if ts in text_df.index:
        for col in text_columns:
            vec = vectorizers[col]
            text = str(text_df.at[ts, col]) if ts in text_df.index else MISSING_TOKEN
            if not text or text.lower() in ["nan", "none", ""]:
                text = MISSING_TOKEN
            tfidf = vec.transform([text]).toarray()[0]
            for i, v in enumerate(tfidf):
                x[f"{col}_tfidf_{i}"] = v

    x = {k: v for k, v in x.items() if pd.notna(v)}

    try:
        # --- RIVER ---
        score = model.score_one(x)
        model.learn_one(x)
        print(f"[{ts}] 🤖 River Score: {score:.4f}")

        # --- REMAND ---
        remand_outliers, remand_flag = remand_compare(x, ts, numeric_df)

        # --- YESTERDAY ---
        y_outliers, y_flag = compare_to_yesterday(x, ts, numeric_df)

        if y_flag:
            print(f"[{ts}] ⚠️ Anomaly vs yesterday | features: {list(y_outliers.keys())}")
        if remand_flag:
            print(f"[{ts}] 🚨 Remand anomaly | features: {list(remand_outliers.keys())}")

        # --- META MODEL ---
        x_meta = {
            "river_score": score,
            "remand_outlier_count": len(remand_outliers) if remand_outliers else 0,
            "yesterday_outlier_count": len(y_outliers) if y_outliers else 0,
            **x  # full state vector
        }

        # Track text changes in last 5 minutes
        prev_ts = ts - pd.Timedelta(CHUNK_SIZE)
        changed_entities = []

        for col in text_columns:
            now = str(text_df.at[ts, col]) if ts in text_df.index else MISSING_TOKEN
            prev = str(text_df.at[prev_ts, col]) if prev_ts in text_df.index else MISSING_TOKEN

            if not now or now.lower() in ["nan", "none", ""]:
                now = MISSING_TOKEN
            if not prev or prev.lower() in ["nan", "none", ""]:
                prev = MISSING_TOKEN

            changed = int(now != prev)
            x_meta[f"{col}_changed_5min"] = changed
            if changed:
                changed_entities.append(col)

        x_meta["changed_entities"] = changed_entities  # for logging

        is_meta_anomaly = meta_model.predict_one(x_meta)
        print(f"[{ts}] 🧠 Meta anomaly? → {is_meta_anomaly} | Changed: {changed_entities}")

        # Optional: implicit label = any model flagged
        y = int(remand_flag or y_flag or score > 0.4)
        meta_model.learn_one(x_meta, y)

    except Exception as e:
        print(f"[{ts}] ⚠️ Skipped due to error: {e}")
# Out:
# [2025-04-14 16:00:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 16:00:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 16:00:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 16:00:00+00:00] 🧠 Meta anomaly? → False | Changed: ['result', '_field', '_measurement', 'domain']
# [2025-04-14 16:00:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 16:05:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 16:05:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 16:05:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 16:05:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 16:10:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 16:10:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 16:10:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 16:10:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 16:15:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 16:15:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 16:15:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 16:15:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 16:20:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 16:20:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 16:20:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 16:20:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 16:25:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 16:25:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 16:25:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 16:25:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 16:30:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 16:30:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 16:30:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 16:30:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 16:35:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 16:35:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 16:35:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 16:35:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 16:40:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 16:40:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 16:40:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 16:40:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 16:45:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 16:45:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 16:45:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 16:45:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 16:50:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 16:50:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 16:50:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 16:50:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 16:55:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 16:55:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 16:55:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 16:55:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 17:00:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 17:00:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 17:00:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 17:00:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 17:05:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 17:05:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 17:05:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 17:05:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 17:10:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 17:10:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 17:10:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 17:10:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 17:15:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 17:15:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 17:15:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 17:15:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 17:20:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 17:20:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 17:20:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 17:20:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 17:25:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 17:25:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 17:25:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 17:25:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 17:30:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 17:30:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 17:30:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 17:30:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 17:35:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 17:35:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 17:35:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 17:35:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 17:40:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 17:40:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 17:40:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 17:40:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 17:45:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 17:45:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 17:45:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 17:45:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 17:50:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 17:50:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 17:50:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 17:50:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 17:55:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 17:55:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 17:55:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 17:55:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 18:00:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 18:00:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 18:00:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 18:00:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 18:05:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 18:05:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 18:05:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 18:05:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 18:10:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 18:10:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 18:10:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 18:10:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 18:15:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 18:15:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 18:15:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 18:15:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 18:20:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 18:20:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 18:20:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 18:20:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 18:25:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 18:25:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 18:25:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 18:25:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 18:30:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 18:30:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 18:30:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 18:30:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 18:35:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 18:35:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 18:35:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 18:35:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 18:40:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 18:40:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 18:40:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 18:40:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 18:45:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 18:45:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 18:45:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 18:45:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 18:50:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 18:50:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 18:50:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 18:50:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 18:55:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 18:55:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 18:55:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 18:55:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 19:00:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 19:00:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 19:00:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 19:00:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 19:05:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 19:05:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 19:05:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 19:05:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 19:10:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 19:10:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 19:10:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 19:10:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 19:15:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 19:15:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 19:15:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 19:15:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 19:20:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 19:20:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 19:20:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 19:20:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 19:25:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 19:25:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 19:25:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 19:25:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 19:30:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 19:30:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 19:30:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 19:30:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 19:35:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 19:35:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 19:35:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 19:35:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 19:40:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 19:40:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 19:40:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 19:40:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 19:45:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 19:45:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 19:45:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 19:45:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 19:50:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 19:50:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 19:50:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 19:50:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 19:55:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 19:55:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 19:55:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 19:55:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 20:00:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 20:00:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 20:00:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 20:00:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 20:05:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 20:05:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 20:05:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 20:05:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 20:10:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 20:10:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 20:10:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 20:10:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 20:15:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 20:15:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 20:15:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 20:15:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 20:20:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 20:20:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 20:20:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 20:20:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 20:25:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 20:25:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 20:25:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 20:25:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 20:30:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 20:30:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 20:30:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 20:30:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 20:35:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 20:35:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 20:35:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 20:35:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 20:40:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 20:40:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 20:40:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 20:40:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 20:45:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 20:45:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 20:45:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 20:45:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 20:50:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 20:50:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 20:50:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 20:50:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 20:55:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 20:55:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 20:55:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 20:55:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 21:00:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 21:00:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 21:00:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 21:00:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 21:05:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 21:05:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 21:05:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 21:05:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 21:10:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 21:10:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 21:10:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 21:10:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 21:15:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 21:15:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 21:15:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 21:15:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 21:20:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 21:20:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 21:20:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 21:20:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 21:25:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 21:25:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 21:25:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 21:25:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 21:30:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 21:30:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 21:30:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 21:30:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 21:35:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 21:35:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 21:35:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 21:35:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 21:40:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 21:40:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 21:40:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 21:40:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 21:45:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 21:45:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 21:45:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 21:45:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 21:50:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 21:50:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 21:50:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 21:50:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 21:55:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 21:55:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 21:55:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 21:55:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 22:00:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 22:00:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 22:00:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 22:00:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 22:05:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 22:05:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 22:05:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 22:05:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 22:10:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 22:10:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 22:10:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 22:10:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 22:15:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 22:15:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 22:15:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 22:15:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 22:20:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 22:20:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 22:20:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 22:20:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 22:25:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 22:25:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 22:25:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 22:25:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 22:30:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 22:30:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 22:30:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 22:30:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 22:35:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 22:35:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 22:35:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 22:35:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 22:40:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 22:40:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 22:40:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 22:40:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 22:45:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 22:45:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 22:45:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 22:45:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 22:50:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 22:50:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 22:50:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 22:50:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 22:55:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 22:55:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 22:55:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 22:55:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 23:00:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 23:00:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 23:00:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 23:00:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 23:05:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 23:05:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 23:05:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 23:05:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 23:10:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 23:10:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 23:10:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 23:10:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 23:15:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 23:15:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 23:15:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 23:15:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 23:20:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 23:20:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 23:20:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 23:20:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 23:25:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 23:25:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 23:25:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 23:25:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 23:30:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 23:30:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 23:30:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 23:30:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 23:35:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 23:35:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 23:35:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 23:35:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 23:40:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 23:40:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 23:40:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 23:40:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 23:45:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 23:45:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 23:45:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 23:45:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 23:50:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 23:50:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 23:50:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 23:50:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-14 23:55:00+00:00] 🤖 River Score: 0.0000
# [2025-04-14 23:55:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-14 23:55:00+00:00] ⚠️ No matching time yesterday
# [2025-04-14 23:55:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-15 00:00:00+00:00] 🤖 River Score: 0.0000
# [2025-04-15 00:00:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-15 00:00:00+00:00] ⚠️ No matching time yesterday
# [2025-04-15 00:00:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-15 00:05:00+00:00] 🤖 River Score: 0.0000
# [2025-04-15 00:05:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-15 00:05:00+00:00] ⚠️ No matching time yesterday
# [2025-04-15 00:05:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-15 00:10:00+00:00] 🤖 River Score: 0.0000
# [2025-04-15 00:10:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-15 00:10:00+00:00] ⚠️ No matching time yesterday
# [2025-04-15 00:10:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-15 00:15:00+00:00] 🤖 River Score: 0.0000
# [2025-04-15 00:15:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-15 00:15:00+00:00] ⚠️ No matching time yesterday
# [2025-04-15 00:15:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-15 00:20:00+00:00] 🤖 River Score: 0.0000
# [2025-04-15 00:20:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-15 00:20:00+00:00] ⚠️ No matching time yesterday
# [2025-04-15 00:20:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-15 00:25:00+00:00] 🤖 River Score: 0.0000
# [2025-04-15 00:25:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-15 00:25:00+00:00] ⚠️ No matching time yesterday
# [2025-04-15 00:25:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-15 00:30:00+00:00] 🤖 River Score: 0.0000
# [2025-04-15 00:30:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-15 00:30:00+00:00] ⚠️ No matching time yesterday
# [2025-04-15 00:30:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-15 00:35:00+00:00] 🤖 River Score: 0.0000
# [2025-04-15 00:35:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-15 00:35:00+00:00] ⚠️ No matching time yesterday
# [2025-04-15 00:35:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-15 00:40:00+00:00] 🤖 River Score: 0.0000
# [2025-04-15 00:40:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-15 00:40:00+00:00] ⚠️ No matching time yesterday
# [2025-04-15 00:40:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-15 00:45:00+00:00] 🤖 River Score: 0.0000
# [2025-04-15 00:45:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-15 00:45:00+00:00] ⚠️ No matching time yesterday
# [2025-04-15 00:45:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-15 00:50:00+00:00] 🤖 River Score: 0.0000
# [2025-04-15 00:50:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-15 00:50:00+00:00] ⚠️ No matching time yesterday
# [2025-04-15 00:50:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-15 00:55:00+00:00] 🤖 River Score: 0.0000
# [2025-04-15 00:55:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-15 00:55:00+00:00] ⚠️ No matching time yesterday
# [2025-04-15 00:55:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-15 01:00:00+00:00] 🤖 River Score: 0.0000
# [2025-04-15 01:00:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-15 01:00:00+00:00] ⚠️ No matching time yesterday
# [2025-04-15 01:00:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-15 01:05:00+00:00] 🤖 River Score: 0.0000
# [2025-04-15 01:05:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-15 01:05:00+00:00] ⚠️ No matching time yesterday
# [2025-04-15 01:05:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-15 01:10:00+00:00] 🤖 River Score: 0.0000
# [2025-04-15 01:10:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-15 01:10:00+00:00] ⚠️ No matching time yesterday
# [2025-04-15 01:10:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-15 01:15:00+00:00] 🤖 River Score: 0.0000
# [2025-04-15 01:15:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-15 01:15:00+00:00] ⚠️ No matching time yesterday
# [2025-04-15 01:15:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'
# [2025-04-15 01:20:00+00:00] 🤖 River Score: 0.0000
# [2025-04-15 01:20:00+00:00] ⚠️ Not enough matching history for remand
# [2025-04-15 01:20:00+00:00] ⚠️ No matching time yesterday
# [2025-04-15 01:20:00+00:00] ⚠️ Skipped due to error: can't multiply sequence by non-int of type 'float'

# %%
# --- Save model and new cutoff ---
with open(SAVE_MODEL_PATH, "wb") as f:
    pickle.dump(model, f)

with open(META_MODEL_PATH, "wb") as f:
    pickle.dump(meta_model, f)

with open(SAVE_TIMESTAMP_PATH, "w") as f:
    f.write(stop)

print("✅ Model updated and saved.")
# Out:
# ✅ Model updated and saved.
